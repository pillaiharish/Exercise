# %%
import numpy as np
import pandas as pd

# %%
a=np.arange(0,5)
a #numpy_array
# Out:
# array([0, 1, 2, 3, 4])

# %%
a_new=pd.DataFrame({'A_column':a})
a_new #pandas_dataframe
# Out:
#    A_column
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4

# %%
b=np.arange(5,10)
b #numpy_array
# Out:
# array([5, 6, 7, 8, 9])

# %%
b_new=pd.DataFrame({'B_column':b})
b_new #pandas_dataframe
# Out:
#    B_column
# 0         5
# 1         6
# 2         7
# 3         8
# 4         9

# %%
a+b #array addition
# Out:
# array([ 5,  7,  9, 11, 13])

# %%
a*b #array mulitplication
# Out:
# array([ 0,  6, 14, 24, 36])

# %%
print(var1)
print('------')
print("for b:"+str(type(b)))
# Out:
# <class 'numpy.ndarray'>
# ------
# for b:<class 'numpy.ndarray'>

# %%
a_new.info()
print('----------')
b_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
# A_column    5 non-null int32
# dtypes: int32(1)
# memory usage: 148.0 bytes
# ----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
# B_column    5 non-null int32
# dtypes: int32(1)
# memory usage: 148.0 bytes

# %%
np.dot(a_new,b_new.T) #dot product of dataframe( transpose is required)
# Out:
# array([[ 0,  0,  0,  0,  0],
#        [ 5,  6,  7,  8,  9],
#        [10, 12, 14, 16, 18],
#        [15, 18, 21, 24, 27],
#        [20, 24, 28, 32, 36]])

# %%
np.dot(a,b) #dot product of arrays
# Out:
# 80

# %%
a_m=np.array([[1, 2], [4, 5],[3,6]])
a_m
# Out:
# array([[1, 2],
#        [4, 5],
#        [3, 6]])

# %%
type(a_m)
# a_m[1]
# Out:
# numpy.ndarray

# %%
a_m_new=pd.DataFrame({'c1':a_m[:,0],'c2':a_m[:,1]})

# %%
a_m_new
# Out:
#    c1  c2
# 0   1   2
# 1   4   5
# 2   3   6

# %%
a_m_new.shape
# Out:
# (3, 2)

# %%
b_m=np.array(np.identity(3))
b_m
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
b_m.dtype
# Out:
# dtype('float64')

# %%
np.random.random(10)
# Out:
# array([0.84201077, 0.85065759, 0.85450682, 0.29710137, 0.07249546,
#        0.70904763, 0.46965802, 0.97489606, 0.62380265, 0.1514756 ])

# %%
Z=np.arange(5,14).reshape(3,3)
Z
# Out:
# array([[ 5,  6,  7],
#        [ 8,  9, 10],
#        [11, 12, 13]])

# %%
[x + 10 for x in Z]
# Out:
# [array([15, 16, 17]), array([18, 19, 20]), array([21, 22, 23])]

# %%
Z>2
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]])

# %%
Z+10
# Out:
# array([[15, 16, 17],
#        [18, 19, 20],
#        [21, 22, 23]])
